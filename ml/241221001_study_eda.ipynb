# %% [markdown]
# ## EDA 란?
# EDA(Exploratory Data Analysis, 탐색적 데이터 분석) 는 데이터를 이해하고, 패턴을 발견하고, 가설을 설정하고, 통찰력을 얻기 위해 데이터를 분석하고 요약하는 중요한 단계입니다. EDA는 모델을 구축하기 전에 데이터를 시각화하고, 통계적 방법 등을 활용하여 데이터의 주요 특징을 파악하는 데 중점을 둡니다.
#
# ## EDA의 주요 목적
#
# - 데이터 이해: 데이터의 구조, 변수 유형, 분포, 결측치 여부 등을 파악합니다.
# - 패턴 발견: 변수 간의 관계, 이상치, 군집 등 숨겨진 패턴을 찾아냅니다.
# - 가설 설정: 데이터 분석을 통해 얻은 통찰력을 바탕으로 모델링에 필요한 가설을 설정합니다.
# - 모델 선택: 데이터의 특징을 이해하여 적합한 머신 러닝 모델을 선택하는 데 도움을 줍니다.
# - 특징 추출 및 생성: 모델 성능을 향상시킬 수 있는 새로운 특징을 추출하거나 생성하는 데 도움을 줍니다.
# - 데이터 전처리: 모델링에 앞서 필요한 데이터 전처리(결측치 처리, 이상치 제거, 변수 변환 등) 방향을 결정합니다.
#
# ## EDA에서 사용되는 주요 기법
#
# - 기술 통계 (Descriptive Statistics):
#   - 중심 경향 (Central Tendency): 평균(mean), 중앙값(median), 최빈값(mode) 등을 통해 데이터의 중심 경향을 파악합니다.
#   - 변동성 (Variability): 분산(variance), 표준편차(standard deviation), 범위(range), 사분위수 범위(IQR) 등을 통해 데이터의 퍼짐 정도를 파악합니다.
#   - 분포 형태 (Shape of Distribution): 왜도(skewness), 첨도(kurtosis) 등을 통해 데이터 분포의 비대칭성과 뾰족한 정도를 파악합니다.
#
# - 데이터 시각화 (Data Visualization):
#   - 히스토그램 (Histogram): 단일 변수의 분포를 시각적으로 나타냅니다.
#   - 산점도 (Scatter Plot): 두 변수 간의 관계를 시각적으로 나타냅니다.
#   - 박스 플롯 (Box Plot): 단일 변수의 분포를 요약하여 보여주며, 이상치를 쉽게 확인할 수 있습니다.
#   - 히트맵 (Heatmap): 여러 변수 간의 상관 관계를 색상으로 나타내어 시각적으로 파악하기 쉽습니다.
#   - 라인 그래프 (Line Graph): 시계열 데이터의 추세를 나타내는 데 유용합니다.
#
# - 데이터 그룹화 (Data Grouping): 데이터를 특정 기준에 따라 그룹화하여 그룹 간의 차이를 비교하고 분석합니다.
#
# - 차원 축소 (Dimensionality Reduction): 고차원 데이터를 저차원으로 축소하여 데이터의 주요 특징을 유지하면서 시각화 및 분석을 용이하게 합니다. (예: PCA, t-SNE)

# %%
# 패키지 import
import numpy as np
import pandas as pd
import sklearn.datasets as D

# %%
# 'ml/data/241221/Global YouTube Statistics.csv' 파일 오픈
data_path = 'data/241221/Global YouTube Statistics.csv'
# !head -3 data_path
# Out:
# 'head'��(��) ���� �Ǵ� �ܺ� ����, ������ �� �ִ� ���α׷�, �Ǵ�
# ��ġ ������ �ƴմϴ�.

# %%
# 데이터 불러오기
data = pd.read_csv(data_path, encoding='latin1')
data.head()
# Out:
#    rank                    Youtuber  subscribers   video views  \
# 0     1                    T-Series    245000000  2.280000e+11
# 1     2              YouTube Movies    170000000  0.000000e+00
# 2     3                     MrBeast    166000000  2.836884e+10
# 3     4  Cocomelon - Nursery Rhymes    162000000  1.640000e+11
# 4     5                   SET India    159000000  1.480000e+11
#
#            category                       Title  uploads        Country  \
# 0             Music                    T-Series    20082          India
# 1  Film & Animation               youtubemovies        1  United States
# 2     Entertainment                     MrBeast      741  United States
# 3         Education  Cocomelon - Nursery Rhymes      966  United States
# 4             Shows                   SET India   116536          India
#
#   Abbreviation   channel_type  ...  subscribers_for_last_30_days  \
# 0           IN          Music  ...                     2000000.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 995 entries, 0 to 994
# Data columns (total 28 columns):
#  #   Column                                   Non-Null Count  Dtype
# ---  ------                                   --------------  -----
#  0   rank                                     995 non-null    int64
#  1   Youtuber                                 995 non-null    object
#  2   subscribers                              995 non-null    int64
#  3   video views                              995 non-null    float64
#  4   category                                 949 non-null    object
#  5   Title                                    995 non-null    object
#  6   uploads                                  995 non-null    int64
#  7   Country                                  873 non-null    object
#  8   Abbreviation                             873 non-null    object
#  9   channel_type                             965 non-null    object
# ...

# %%
# 범주형 변수 타입 확인
feature_name = 'channel_type'
# data[feature_name]

data[feature_name].unique()
# Out:
# array(['Music', 'Games', 'Entertainment', 'Education', 'People', 'Sports',
#        'Film', 'News', nan, 'Comedy', 'Howto', 'Nonprofit', 'Autos',
#        'Tech', 'Animals'], dtype=object)

# %%
# 각 범주별로 샘플이 몇 개인지 확인
data[feature_name].value_counts()
# Out:
# channel_type
# Entertainment    304
# Music            216
# People           101
# Games             98
# Comedy            51
# Education         49
# Film              42
# Howto             36
# News              30
# Tech              17
# Sports            13
# Autos              3
# Animals            3
# Nonprofit          2
# Name: count, dtype: int64

# %%
data.iloc[723]
# Out:
# rank                                                   724
# Youtuber                                          ABC News
# subscribers                                       14700000
# video views                                  12961669452.0
# category                                   News & Politics
# Title                                             ABC News
# uploads                                              80830
# Country                                      United States
# Abbreviation                                            US
# channel_type                                          News
# video_views_rank                                     289.0
# country_rank                                         154.0
# channel_type_rank                                     18.0
# video_views_for_the_last_30_days               185709000.0
# lowest_monthly_earnings                            46400.0
# highest_monthly_earnings                          742800.0
# ...

# %%
# 결측값 확인
data.isnull().sum()
# Out:
# rank                                         0
# Youtuber                                     0
# subscribers                                  0
# video views                                  0
# category                                    46
# Title                                        0
# uploads                                      0
# Country                                    122
# Abbreviation                               122
# channel_type                                30
# video_views_rank                             1
# country_rank                               116
# channel_type_rank                           33
# video_views_for_the_last_30_days            56
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days               337
# created_year                                 5
# ...

# %%
# 결측치를 하나라도 포함하는 인덱스 확인
# missing_data_indices = data[data.isnull().any(axis=1)].index
# missing_data_indices
sample_indices_with_nan = data.isnull().sum(axis=1) > 0
print(type(sample_indices_with_nan))
data[sample_indices_with_nan]
# Out:
# <class 'pandas.core.series.Series'>
#      rank             Youtuber  subscribers   video views          category  \
# 1       2       YouTube Movies    170000000  0.000000e+00  Film & Animation
# 5       6                Music    119000000  0.000000e+00               NaN
# 6       7  ýýý Kids Diana Show    112000000  9.324704e+10    People & Blogs
# 7       8            PewDiePie    111000000  2.905804e+10            Gaming
# 12     13               Gaming     93600000  0.000000e+00               NaN
# ..    ...                  ...          ...           ...               ...
# 983   984             MoniLina     12400000  1.608681e+10            Comedy
# 985   986                 TKOR     12400000  3.392023e+09         Education
# 986   987            ANNA KOVA     12400000  1.395959e+10    People & Blogs
# 987   988        Avril Lavigne     12400000  6.202090e+09             Music
# 992   993                Panda     12300000  2.214684e+09               NaN
#
# ...

# %%
data[data.isnull().sum(axis=1) > 3]
# Out:
#      rank                                           Youtuber  subscribers  \
# 5       6                                              Music    119000000
# 12     13                                             Gaming     93600000
# 14     15                                          Goldmines     86900000
# 38     39  LooLoo Kids - Nursery Rhymes and Children's Songs     54000000
# 48     49                                            Badabun     46800000
# ..    ...                                                ...          ...
# 958   959                                     Troom Troom PT     12500000
# 967   968                              Troom Troom Indonesia     12500000
# 972   973                                   Hero Movies 2023     12400000
# 985   986                                               TKOR     12400000
# 986   987                                          ANNA KOVA     12400000
#
#       video views          category  \
# 5    0.000000e+00               NaN
# ...

# %%
# 결측치가 많아서 분석하기 어려운 특성값들 출력
threshold = 121  # 결측치가 122개 이상인 특성값들
missing_data = data.isnull().sum()
difficult_features = missing_data[missing_data > threshold]
print(difficult_features)
# Out:
# Country                                    122
# Abbreviation                               122
# subscribers_for_last_30_days               337
# Gross tertiary education enrollment (%)    123
# Population                                 123
# Unemployment rate                          123
# Urban_population                           123
# Latitude                                   123
# Longitude                                  123
# dtype: int64

# %%
try:
    difficult_features.drop('subscribers_for_last_30_days', inplace=True)
except:
    pass
columns_with_nan = difficult_features.index.tolist()
print(type(columns_with_nan))
columns_with_nan
# Out:
# <class 'list'>
# ['Country',
#  'Abbreviation',
#  'Gross tertiary education enrollment (%)',
#  'Population',
#  'Unemployment rate',
#  'Urban_population',
#  'Latitude',
#  'Longitude']

# %%
# 연산이 가능한 행들만 선택
numeric_data = data.select_dtypes(include=[np.number])
numeric_data[numeric_data < 0].count()
# Out:
# rank                                         0
# subscribers                                  0
# video views                                  0
# uploads                                      0
# video_views_rank                             0
# country_rank                                 0
# channel_type_rank                            0
# video_views_for_the_last_30_days             0
# lowest_monthly_earnings                      0
# highest_monthly_earnings                     0
# lowest_yearly_earnings                       0
# highest_yearly_earnings                      0
# subscribers_for_last_30_days                 0
# created_year                                 0
# created_date                                 0
# Gross tertiary education enrollment (%)      0
# Population                                   0
# Unemployment rate                            0
# Urban_population                             0
# Latitude                                   119
# ...

# %%
data.columns
# Out:
# Index(['rank', 'Youtuber', 'subscribers', 'video views', 'category', 'Title',
#        'uploads', 'Country', 'Abbreviation', 'channel_type',
#        'video_views_rank', 'country_rank', 'channel_type_rank',
#        'video_views_for_the_last_30_days', 'lowest_monthly_earnings',
#        'highest_monthly_earnings', 'lowest_yearly_earnings',
#        'highest_yearly_earnings', 'subscribers_for_last_30_days',
#        'created_year', 'created_month', 'created_date',
#        'Gross tertiary education enrollment (%)', 'Population',
#        'Unemployment rate', 'Urban_population', 'Latitude', 'Longitude'],
#       dtype='object')

# %%
data.dtypes
# Out:
# rank                                         int64
# Youtuber                                    object
# subscribers                                  int64
# video views                                float64
# category                                    object
# Title                                       object
# uploads                                      int64
# Country                                     object
# Abbreviation                                object
# channel_type                                object
# video_views_rank                           float64
# country_rank                               float64
# channel_type_rank                          float64
# video_views_for_the_last_30_days           float64
# lowest_monthly_earnings                    float64
# highest_monthly_earnings                   float64
# lowest_yearly_earnings                     float64
# highest_yearly_earnings                    float64
# ...

# %%
(data['subscribers'] < 0).any()
# Out:
# np.False_

# %%
# 위도와 경도의 최소, 최대값 확인
latitude_min = data['Latitude'].min()
latitude_max = data['Latitude'].max()
longitude_min = data['Longitude'].min()
longitude_max = data['Longitude'].max()

print(f"위도의 최소값: {latitude_min}, 최대값: {latitude_max}")
print(f"경도의 최소값: {longitude_min}, 최대값: {longitude_max}")
# Out:
# 위도의 최소값: -38.416097, 최대값: 61.92411
# 경도의 최소값: -172.104629, 최대값: 138.252924

# %%
data.describe()
# Out:
#             rank   subscribers   video views        uploads  video_views_rank  \
# count  995.00000  9.950000e+02  9.950000e+02     995.000000      9.940000e+02
# mean   498.00000  2.298241e+07  1.103954e+10    9187.125628      5.542489e+05
# std    287.37606  1.752611e+07  1.411084e+10   34151.352254      1.362782e+06
# min      1.00000  1.230000e+07  0.000000e+00       0.000000      1.000000e+00
# 25%    249.50000  1.450000e+07  4.288145e+09     194.500000      3.230000e+02
# 50%    498.00000  1.770000e+07  7.760820e+09     729.000000      9.155000e+02
# 75%    746.50000  2.460000e+07  1.355470e+10    2667.500000      3.584500e+03
# max    995.00000  2.450000e+08  2.280000e+11  301308.000000      4.057944e+06
#
#        country_rank  channel_type_rank  video_views_for_the_last_30_days  \
# count    879.000000         962.000000                      9.390000e+02
# mean     386.053470         745.719335                      1.756103e+08
# ...

# %%
# 데이터 시각화 패키지
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# 월별 수입의 평균을 박스플롯으로 시각화
target_feagure = 'lowest_monthly_earnings'
sns.boxplot(data=data, y=target_feagure)
plt.show()

# %%
# 히스토그램
sns.histplot(data=data, x=target_feagure)
plt.show()

# %%
# 로그스케일로 확인하기
sns.histplot(data=data, x=target_feagure, log_scale=(False, True))
plt.show()

# %%
# 막대그래프의 막대로 범주를 확인할 변수
category_feature = 'category'
# 막대그래프의 높이로 값을 확인할 변수
target_feature = 'lowest_monthly_earnings'

# 막대 그래프 생성
barplot = sns.barplot(data=data, x=category_feature, y=target_feature, color='C0', errorbar=None)

# matplotlib에서 x축 레이블의 위치, 방향 설정 변경
loc, labels = plt.xticks()
barplot.set_xticklabels(labels, rotation=90)

plt.show()
# Out:
# C:\Users\YoungJin\AppData\Local\Temp\ipykernel_12344\4074481908.py:11: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   barplot.set_xticklabels(labels, rotation=90)
